# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
npz = np.load("Audiobooks_data_train.npz")

train_inputs = npz["inputs"].astype(np.float)
train_targets = npz["targets"].astype(np.int)

npz = np.load("Audiobooks_data_validation.npz")
validation_inputs, validation_targets = npz["inputs"].astype(np.float), npz["targets"].astype(np.int)

npz = np.load("Audiobooks_data_test.npz")
test_inputs, test_targets = npz["inputs"].astype(np.float), npz["targets"].astype(np.int)

# %% [markdown]
# ### Model

# %%
input_size = 10
output_size = 2
hidden_layer_size = 100

model = tf.keras.Sequential([
    
    tf.keras.layers.Dense(hidden_layer_size, activation="relu"),
    tf.keras.layers.Dense(hidden_layer_size, activation="relu"),
    tf.keras.layers.Dense(output_size, activation="softmax")
    ])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

batch_size = 100

max_epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs, 
          train_targets, 
          batch_size = batch_size,
          epochs=max_epochs,
          callbacks=[early_stopping],
          validation_data=(validation_inputs, validation_targets),
          verbose = 2        
         )
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 1s - loss: 0.4643 - accuracy: 0.8435 - val_loss: 0.3013 - val_accuracy: 0.9060
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3238 - accuracy: 0.8826 - val_loss: 0.2549 - val_accuracy: 0.9038
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.2911 - accuracy: 0.8921 - val_loss: 0.2349 - val_accuracy: 0.9083
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.2765 - accuracy: 0.8941 - val_loss: 0.2323 - val_accuracy: 0.9195
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2663 - accuracy: 0.8980 - val_loss: 0.2368 - val_accuracy: 0.9284
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2628 - accuracy: 0.9003 - val_loss: 0.2244 - val_accuracy: 0.9217
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2604 - accuracy: 0.9022 - val_loss: 0.2256 - val_accuracy: 0.9217
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2514 - accuracy: 0.9030 - val_loss: 0.2229 - val_accuracy: 0.9239
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.2490 - accuracy: 0.9056 - val_loss: 0.2206 - val_accuracy: 0.9239
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.2472 - accuracy: 0.9042 - val_loss: 0.2331 - val_accuracy: 0.9262
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.2441 - accuracy: 0.9070 - val_loss: 0.2175 - val_accuracy: 0.9262
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.2399 - accuracy: 0.9086 - val_loss: 0.2131 - val_accuracy: 0.9239
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.2402 - accuracy: 0.9089 - val_loss: 0.2195 - val_accuracy: 0.9262
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.2372 - accuracy: 0.9092 - val_loss: 0.2146 - val_accuracy: 0.9262

# %% [markdown]
# ### Test the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 448/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print("Test loss: {0:.2f}, Test accuracy: {1:.2f}%".format(test_loss, test_accuracy*100))
# Out:
# Test loss: 0.24, Test accuracy: 91.29%
